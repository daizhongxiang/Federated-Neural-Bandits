# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm

# %%
def plot_mean_and_CI_with_marker(time_steps, mean, lb, ub, color_mean=None, color_shading=None, marker=None, marker_size=12):
    plt.fill_between(time_steps, ub, lb,
                     color=color_shading, alpha=.2)
    plt.plot(time_steps, mean, color_mean, marker=marker, markersize=marker_size, markevery=500)

# %% [markdown]
# # cosine

# %%
all_regrets_1 = []
all_regrets_2 = []
all_regrets_3 = []
all_regrets_4 = []
all_regrets_5 = []
all_regrets_6 = []

run_list = np.arange(3)
for itr in run_list:
    dataset = "cosine"
    depth = 1
    width = 20
    lam, nu = 0.1, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_1.append(values_acc)

    dataset = "cosine"
    depth = 1
    width = 20
    lam, nu = 0.1, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    log_file_name = log_file_name[:-4] + "_ts.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_2.append(values_acc)

    dataset = "cosine"
    N = 1
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_3.append(values_acc)
    
    dataset = "cosine"
    N = 2
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_4.append(values_acc)

    dataset = "cosine"
    N = 5
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_5.append(values_acc)
    
    dataset = "cosine"
    N = 10
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_6.append(values_acc)

all_regrets_1_np = np.array(all_regrets_1)
all_regrets_2_np = np.array(all_regrets_2)
all_regrets_3_np = np.array(all_regrets_3)
all_regrets_4_np = np.array(all_regrets_4)
all_regrets_5_np = np.array(all_regrets_5)
all_regrets_6_np = np.array(all_regrets_6)

all_regrets_1_np_mean = np.mean(all_regrets_1_np, axis=0)
all_regrets_2_np_mean = np.mean(all_regrets_2_np, axis=0)
all_regrets_3_np_mean = np.mean(all_regrets_3_np, axis=0)
all_regrets_4_np_mean = np.mean(all_regrets_4_np, axis=0)
all_regrets_5_np_mean = np.mean(all_regrets_5_np, axis=0)
all_regrets_6_np_mean = np.mean(all_regrets_6_np, axis=0)

all_regrets_1_np_stderr = np.std(all_regrets_1_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_2_np_stderr = np.std(all_regrets_2_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_3_np_stderr = np.std(all_regrets_3_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_4_np_stderr = np.std(all_regrets_4_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_5_np_stderr = np.std(all_regrets_5_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_6_np_stderr = np.std(all_regrets_6_np, axis=0) / (np.sqrt(len(run_list)))

all_regrets_1_np_ub = all_regrets_1_np_mean + all_regrets_1_np_stderr
all_regrets_1_np_lb = all_regrets_1_np_mean - all_regrets_1_np_stderr
all_regrets_2_np_ub = all_regrets_2_np_mean + all_regrets_2_np_stderr
all_regrets_2_np_lb = all_regrets_2_np_mean - all_regrets_2_np_stderr
all_regrets_3_np_ub = all_regrets_3_np_mean + all_regrets_3_np_stderr
all_regrets_3_np_lb = all_regrets_3_np_mean - all_regrets_3_np_stderr
all_regrets_4_np_ub = all_regrets_4_np_mean + all_regrets_4_np_stderr
all_regrets_4_np_lb = all_regrets_4_np_mean - all_regrets_4_np_stderr
all_regrets_5_np_ub = all_regrets_5_np_mean + all_regrets_5_np_stderr
all_regrets_5_np_lb = all_regrets_5_np_mean - all_regrets_5_np_stderr
all_regrets_6_np_ub = all_regrets_6_np_mean + all_regrets_6_np_stderr
all_regrets_6_np_lb = all_regrets_6_np_mean - all_regrets_6_np_stderr

# %%
lw = 2.0
plt.rc('font', size=22)
plt.figure(figsize=(8, 6))
plt.rcParams["legend.framealpha"] = 0.5
plt.rcParams["legend.loc"] = "best"

inds = np.arange(1, 100000)
plot_len = 5000

plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_1_np_mean[:plot_len], all_regrets_1_np_ub[:plot_len], all_regrets_1_np_lb[:plot_len], color_mean="b", color_shading="b", marker="v", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_2_np_mean[:plot_len], all_regrets_2_np_ub[:plot_len], all_regrets_2_np_lb[:plot_len], color_mean="r", color_shading="r", marker="D", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_3_np_mean[:plot_len], all_regrets_3_np_ub[:plot_len], all_regrets_3_np_lb[:plot_len], color_mean="g", color_shading="g", marker="s", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_4_np_mean[:plot_len], all_regrets_4_np_ub[:plot_len], all_regrets_4_np_lb[:plot_len], color_mean="c", color_shading="c", marker="o", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_5_np_mean[:plot_len], all_regrets_5_np_ub[:plot_len], all_regrets_5_np_lb[:plot_len], color_mean="y", color_shading="y", marker="x", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_6_np_mean[:plot_len], all_regrets_6_np_ub[:plot_len], all_regrets_6_np_lb[:plot_len], color_mean="m", color_shading="m", marker="^", marker_size=12)

plt.legend((r"Neural UCB", r"Neural TS", \
            r"FN-UCB ($N=1$)", r"FN-UCB ($N=2$)", r"FN-UCB ($N=5$)", r"FN-UCB ($N=10$)", \
           ), prop={'size':16})

axes = plt.gca()
axes.set_xlim([0, 5000])
axes.set_ylim([0, 130])

plt.title("cosine, Fig. 1a")
plt.ylabel("Cumulative Regret")
plt.xlabel("Iterations")

plt.show()

# %% [markdown]
# # square

# %%
all_regrets_1 = []
all_regrets_2 = []
all_regrets_3 = []
all_regrets_4 = []
all_regrets_5 = []
all_regrets_6 = []

run_list = np.arange(3)
for itr in run_list:
    dataset = "square"
    depth = 1
    width = 20
    lam, nu = 0.1, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_1.append(values_acc)

    dataset = "square"
    depth = 1
    width = 20
    lam, nu = 0.1, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    log_file_name = log_file_name[:-4] + "_ts.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_2.append(values_acc)

    dataset = "square"
    N = 1
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_3.append(values_acc)
    
    dataset = "square"
    N = 2
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_4.append(values_acc)

    dataset = "square"
    N = 5
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_5.append(values_acc)
    
    dataset = "square"
    N = 10
    depth = 1
    width = 20
    lam, nu = 0.1, 0.1
    local_training_iter = 30
    nu_2 = 0.1
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_6.append(values_acc)

all_regrets_1_np = np.array(all_regrets_1)
all_regrets_2_np = np.array(all_regrets_2)
all_regrets_3_np = np.array(all_regrets_3)
all_regrets_4_np = np.array(all_regrets_4)
all_regrets_5_np = np.array(all_regrets_5)
all_regrets_6_np = np.array(all_regrets_6)

all_regrets_1_np_mean = np.mean(all_regrets_1_np, axis=0)
all_regrets_2_np_mean = np.mean(all_regrets_2_np, axis=0)
all_regrets_3_np_mean = np.mean(all_regrets_3_np, axis=0)
all_regrets_4_np_mean = np.mean(all_regrets_4_np, axis=0)
all_regrets_5_np_mean = np.mean(all_regrets_5_np, axis=0)
all_regrets_6_np_mean = np.mean(all_regrets_6_np, axis=0)

all_regrets_1_np_stderr = np.std(all_regrets_1_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_2_np_stderr = np.std(all_regrets_2_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_3_np_stderr = np.std(all_regrets_3_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_4_np_stderr = np.std(all_regrets_4_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_5_np_stderr = np.std(all_regrets_5_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_6_np_stderr = np.std(all_regrets_6_np, axis=0) / (np.sqrt(len(run_list)))

all_regrets_1_np_ub = all_regrets_1_np_mean + all_regrets_1_np_stderr
all_regrets_1_np_lb = all_regrets_1_np_mean - all_regrets_1_np_stderr
all_regrets_2_np_ub = all_regrets_2_np_mean + all_regrets_2_np_stderr
all_regrets_2_np_lb = all_regrets_2_np_mean - all_regrets_2_np_stderr
all_regrets_3_np_ub = all_regrets_3_np_mean + all_regrets_3_np_stderr
all_regrets_3_np_lb = all_regrets_3_np_mean - all_regrets_3_np_stderr
all_regrets_4_np_ub = all_regrets_4_np_mean + all_regrets_4_np_stderr
all_regrets_4_np_lb = all_regrets_4_np_mean - all_regrets_4_np_stderr
all_regrets_5_np_ub = all_regrets_5_np_mean + all_regrets_5_np_stderr
all_regrets_5_np_lb = all_regrets_5_np_mean - all_regrets_5_np_stderr
all_regrets_6_np_ub = all_regrets_6_np_mean + all_regrets_6_np_stderr
all_regrets_6_np_lb = all_regrets_6_np_mean - all_regrets_6_np_stderr

# %%
lw = 2.0
plt.rc('font', size=22)
plt.figure(figsize=(8, 6))
plt.rcParams["legend.framealpha"] = 0.5
plt.rcParams["legend.loc"] = "best"

inds = np.arange(1, 100000)
plot_len = 5000

plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_1_np_mean[:plot_len], all_regrets_1_np_ub[:plot_len], all_regrets_1_np_lb[:plot_len], color_mean="b", color_shading="b", marker="v", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_2_np_mean[:plot_len], all_regrets_2_np_ub[:plot_len], all_regrets_2_np_lb[:plot_len], color_mean="r", color_shading="r", marker="D", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_3_np_mean[:plot_len], all_regrets_3_np_ub[:plot_len], all_regrets_3_np_lb[:plot_len], color_mean="g", color_shading="g", marker="s", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_4_np_mean[:plot_len], all_regrets_4_np_ub[:plot_len], all_regrets_4_np_lb[:plot_len], color_mean="c", color_shading="c", marker="o", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_5_np_mean[:plot_len], all_regrets_5_np_ub[:plot_len], all_regrets_5_np_lb[:plot_len], color_mean="y", color_shading="y", marker="x", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_6_np_mean[:plot_len], all_regrets_6_np_ub[:plot_len], all_regrets_6_np_lb[:plot_len], color_mean="m", color_shading="m", marker="^", marker_size=12)

plt.legend((r"Neural UCB", r"Neural TS", \
            r"FN-UCB ($N=1$)", r"FN-UCB ($N=2$)", r"FN-UCB ($N=5$)", r"FN-UCB ($N=10$)", \
           ), prop={'size':16})

axes = plt.gca()
axes.set_xlim([0, 5000])
# axes.set_ylim([0, 130])

plt.title("square, Fig. 1b")
plt.ylabel("Cumulative Regret")
plt.xlabel("Iterations")

plt.show()

# %% [markdown]
# # shuttle

# %% [markdown]
# ## no diagonalization

# %%
all_regrets_1 = []
all_regrets_2 = []
all_regrets_3 = []
all_regrets_4 = []
all_regrets_5 = []

run_list = np.arange(3)
for itr in run_list:
    dataset = "shuttle"
    depth = 1
    width = 20
    lam, nu = 10, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_1.append(values_acc)

    dataset = "shuttle"
    depth = 1
    width = 20
    lam, nu = 10, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    log_file_name = log_file_name[:-4] + "_ts.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_2.append(values_acc)

    dataset = "shuttle"
    N = 1
    depth = 1
    width = 20
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_3.append(values_acc)
    
    dataset = "shuttle"
    N = 2
    depth = 1
    width = 20
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_4.append(values_acc)

    dataset = "shuttle"
    N = 5
    depth = 1
    width = 20
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_5.append(values_acc)
    

all_regrets_1_np = np.array(all_regrets_1)
all_regrets_2_np = np.array(all_regrets_2)
all_regrets_3_np = np.array(all_regrets_3)
all_regrets_4_np = np.array(all_regrets_4)
all_regrets_5_np = np.array(all_regrets_5)

all_regrets_1_np_mean = np.mean(all_regrets_1_np, axis=0)
all_regrets_2_np_mean = np.mean(all_regrets_2_np, axis=0)
all_regrets_3_np_mean = np.mean(all_regrets_3_np, axis=0)
all_regrets_4_np_mean = np.mean(all_regrets_4_np, axis=0)
all_regrets_5_np_mean = np.mean(all_regrets_5_np, axis=0)

all_regrets_1_np_stderr = np.std(all_regrets_1_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_2_np_stderr = np.std(all_regrets_2_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_3_np_stderr = np.std(all_regrets_3_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_4_np_stderr = np.std(all_regrets_4_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_5_np_stderr = np.std(all_regrets_5_np, axis=0) / (np.sqrt(len(run_list)))

all_regrets_1_np_ub = all_regrets_1_np_mean + all_regrets_1_np_stderr
all_regrets_1_np_lb = all_regrets_1_np_mean - all_regrets_1_np_stderr
all_regrets_2_np_ub = all_regrets_2_np_mean + all_regrets_2_np_stderr
all_regrets_2_np_lb = all_regrets_2_np_mean - all_regrets_2_np_stderr
all_regrets_3_np_ub = all_regrets_3_np_mean + all_regrets_3_np_stderr
all_regrets_3_np_lb = all_regrets_3_np_mean - all_regrets_3_np_stderr
all_regrets_4_np_ub = all_regrets_4_np_mean + all_regrets_4_np_stderr
all_regrets_4_np_lb = all_regrets_4_np_mean - all_regrets_4_np_stderr
all_regrets_5_np_ub = all_regrets_5_np_mean + all_regrets_5_np_stderr
all_regrets_5_np_lb = all_regrets_5_np_mean - all_regrets_5_np_stderr

# %%
lw = 2.0
plt.rc('font', size=22)
plt.figure(figsize=(8, 6))
plt.rcParams["legend.framealpha"] = 0.5
plt.rcParams["legend.loc"] = "best"

inds = np.arange(1, 100000)
plot_len = 5000

plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_1_np_mean[:plot_len], all_regrets_1_np_ub[:plot_len], all_regrets_1_np_lb[:plot_len], color_mean="b", color_shading="b", marker="v", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_2_np_mean[:plot_len], all_regrets_2_np_ub[:plot_len], all_regrets_2_np_lb[:plot_len], color_mean="r", color_shading="r", marker="D", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_3_np_mean[:plot_len], all_regrets_3_np_ub[:plot_len], all_regrets_3_np_lb[:plot_len], color_mean="g", color_shading="g", marker="s", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_4_np_mean[:plot_len], all_regrets_4_np_ub[:plot_len], all_regrets_4_np_lb[:plot_len], color_mean="c", color_shading="c", marker="o", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_5_np_mean[:plot_len], all_regrets_5_np_ub[:plot_len], all_regrets_5_np_lb[:plot_len], color_mean="y", color_shading="y", marker="x", marker_size=12)

plt.legend((r"Neural UCB", r"Neural TS", \
            r"FN-UCB ($N=1$)", r"FN-UCB ($N=2$)", r"FN-UCB ($N=5$)", \
           ), prop={'size':16})

axes = plt.gca()
axes.set_xlim([0, 5000])
axes.set_ylim([0, 800])

plt.title("shuttle, no diagonalization, Fig. 2a")
plt.ylabel("Cumulative Regret")
plt.xlabel("Iterations")

plt.show()

# %% [markdown]
# ## with diagonalization

# %%
all_regrets_1 = []
all_regrets_2 = []
all_regrets_3 = []
all_regrets_4 = []
all_regrets_5 = []

run_list = np.arange(3)
for itr in run_list:
    dataset = "shuttle"
    depth = 1
    width = 50
    lam, nu = 10, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    log_file_name = log_file_name[:-4] + "_diag.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_1.append(values_acc)

    dataset = "shuttle"
    depth = 1
    width = 50
    lam, nu = 10, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    log_file_name = log_file_name[:-4] + "_diag.pkl"
    log_file_name = log_file_name[:-4] + "_ts.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_2.append(values_acc)

    dataset = "shuttle"
    N = 1
    depth = 1
    width = 50
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    log_file_name = log_file_name[:-4] + "_diag.pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_3.append(values_acc)
    
    dataset = "shuttle"
    N = 2
    depth = 1
    width = 50
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    log_file_name = log_file_name[:-4] + "_diag.pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_4.append(values_acc)

    dataset = "shuttle"
    N = 5
    depth = 1
    width = 50
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    log_file_name = log_file_name[:-4] + "_diag.pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_5.append(values_acc)
    

all_regrets_1_np = np.array(all_regrets_1)
all_regrets_2_np = np.array(all_regrets_2)
all_regrets_3_np = np.array(all_regrets_3)
all_regrets_4_np = np.array(all_regrets_4)
all_regrets_5_np = np.array(all_regrets_5)

all_regrets_1_np_mean = np.mean(all_regrets_1_np, axis=0)
all_regrets_2_np_mean = np.mean(all_regrets_2_np, axis=0)
all_regrets_3_np_mean = np.mean(all_regrets_3_np, axis=0)
all_regrets_4_np_mean = np.mean(all_regrets_4_np, axis=0)
all_regrets_5_np_mean = np.mean(all_regrets_5_np, axis=0)

all_regrets_1_np_stderr = np.std(all_regrets_1_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_2_np_stderr = np.std(all_regrets_2_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_3_np_stderr = np.std(all_regrets_3_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_4_np_stderr = np.std(all_regrets_4_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_5_np_stderr = np.std(all_regrets_5_np, axis=0) / (np.sqrt(len(run_list)))

all_regrets_1_np_ub = all_regrets_1_np_mean + all_regrets_1_np_stderr
all_regrets_1_np_lb = all_regrets_1_np_mean - all_regrets_1_np_stderr
all_regrets_2_np_ub = all_regrets_2_np_mean + all_regrets_2_np_stderr
all_regrets_2_np_lb = all_regrets_2_np_mean - all_regrets_2_np_stderr
all_regrets_3_np_ub = all_regrets_3_np_mean + all_regrets_3_np_stderr
all_regrets_3_np_lb = all_regrets_3_np_mean - all_regrets_3_np_stderr
all_regrets_4_np_ub = all_regrets_4_np_mean + all_regrets_4_np_stderr
all_regrets_4_np_lb = all_regrets_4_np_mean - all_regrets_4_np_stderr
all_regrets_5_np_ub = all_regrets_5_np_mean + all_regrets_5_np_stderr
all_regrets_5_np_lb = all_regrets_5_np_mean - all_regrets_5_np_stderr

# %%
lw = 2.0
plt.rc('font', size=22)
plt.figure(figsize=(8, 6))
plt.rcParams["legend.framealpha"] = 0.5
plt.rcParams["legend.loc"] = "best"

inds = np.arange(1, 100000)
plot_len = 5000

plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_1_np_mean[:plot_len], all_regrets_1_np_ub[:plot_len], all_regrets_1_np_lb[:plot_len], color_mean="b", color_shading="b", marker="v", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_2_np_mean[:plot_len], all_regrets_2_np_ub[:plot_len], all_regrets_2_np_lb[:plot_len], color_mean="r", color_shading="r", marker="D", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_3_np_mean[:plot_len], all_regrets_3_np_ub[:plot_len], all_regrets_3_np_lb[:plot_len], color_mean="g", color_shading="g", marker="s", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_4_np_mean[:plot_len], all_regrets_4_np_ub[:plot_len], all_regrets_4_np_lb[:plot_len], color_mean="c", color_shading="c", marker="o", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_5_np_mean[:plot_len], all_regrets_5_np_ub[:plot_len], all_regrets_5_np_lb[:plot_len], color_mean="y", color_shading="y", marker="x", marker_size=12)

plt.legend((r"Neural UCB", r"Neural TS", \
            r"FN-UCB ($N=1$)", r"FN-UCB ($N=2$)", r"FN-UCB ($N=5$)", \
           ), prop={'size':16})

axes = plt.gca()
axes.set_xlim([0, 5000])
axes.set_ylim([0, 305])

plt.title("shuttle, with diagonalization, Fig. 2c")
plt.ylabel("Cumulative Regret")
plt.xlabel("Iterations")

plt.show()

# %% [markdown]
# # magic telescope

# %%
all_regrets_1 = []
all_regrets_2 = []
all_regrets_3 = []
all_regrets_4 = []
all_regrets_5 = []

run_list = np.arange(3)
for itr in run_list:
    dataset = "MagicTelescope"
    depth = 1
    width = 20
    lam, nu = 10, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_1.append(values_acc)

    dataset = "MagicTelescope"
    depth = 1
    width = 20
    lam, nu = 10, 0.01
    local_training_iter = 30
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_train_steps_" + str(local_training_iter) + "_neural_ucb.pkl"
    log_file_name = log_file_name[:-4] + "_ts.pkl"
    regrets = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(regrets)
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_2.append(values_acc)

    dataset = "MagicTelescope"
    N = 1
    depth = 1
    width = 20
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_3.append(values_acc)
    
    dataset = "MagicTelescope"
    N = 2
    depth = 1
    width = 20
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_4.append(values_acc)

    dataset = "MagicTelescope"
    N = 5
    depth = 1
    width = 20
    lam, nu = 10, 0.1
    local_training_iter = 30
    nu_2 = 0.01
    log_file_name = "results_fn_ucb/regret_iter_" + str(itr) + "_dataset_" + dataset + \
                "_N_" + str(N) + \
                "_depth_" + str(depth) + "_width_" + str(width) + "_lam_" + str(lam) + \
                "_nu_" + str(nu) + "_nu2_" + str(nu_2) + \
                "_train_steps_" + str(local_training_iter) + ".pkl"
    res = pickle.load(open(log_file_name, "rb"))
    regrets = np.array(res["regrets"])
    values = np.mean(regrets, axis=1)
    values_acc = np.cumsum(values)
    all_regrets_5.append(values_acc)
    

all_regrets_1_np = np.array(all_regrets_1)
all_regrets_2_np = np.array(all_regrets_2)
all_regrets_3_np = np.array(all_regrets_3)
all_regrets_4_np = np.array(all_regrets_4)
all_regrets_5_np = np.array(all_regrets_5)

all_regrets_1_np_mean = np.mean(all_regrets_1_np, axis=0)
all_regrets_2_np_mean = np.mean(all_regrets_2_np, axis=0)
all_regrets_3_np_mean = np.mean(all_regrets_3_np, axis=0)
all_regrets_4_np_mean = np.mean(all_regrets_4_np, axis=0)
all_regrets_5_np_mean = np.mean(all_regrets_5_np, axis=0)

all_regrets_1_np_stderr = np.std(all_regrets_1_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_2_np_stderr = np.std(all_regrets_2_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_3_np_stderr = np.std(all_regrets_3_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_4_np_stderr = np.std(all_regrets_4_np, axis=0) / (np.sqrt(len(run_list)))
all_regrets_5_np_stderr = np.std(all_regrets_5_np, axis=0) / (np.sqrt(len(run_list)))

all_regrets_1_np_ub = all_regrets_1_np_mean + all_regrets_1_np_stderr
all_regrets_1_np_lb = all_regrets_1_np_mean - all_regrets_1_np_stderr
all_regrets_2_np_ub = all_regrets_2_np_mean + all_regrets_2_np_stderr
all_regrets_2_np_lb = all_regrets_2_np_mean - all_regrets_2_np_stderr
all_regrets_3_np_ub = all_regrets_3_np_mean + all_regrets_3_np_stderr
all_regrets_3_np_lb = all_regrets_3_np_mean - all_regrets_3_np_stderr
all_regrets_4_np_ub = all_regrets_4_np_mean + all_regrets_4_np_stderr
all_regrets_4_np_lb = all_regrets_4_np_mean - all_regrets_4_np_stderr
all_regrets_5_np_ub = all_regrets_5_np_mean + all_regrets_5_np_stderr
all_regrets_5_np_lb = all_regrets_5_np_mean - all_regrets_5_np_stderr

# %%
lw = 2.0
plt.rc('font', size=22)
plt.figure(figsize=(8, 6))
plt.rcParams["legend.framealpha"] = 0.5
plt.rcParams["legend.loc"] = "best"

inds = np.arange(1, 100000)
plot_len = 5000

plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_1_np_mean[:plot_len], all_regrets_1_np_ub[:plot_len], all_regrets_1_np_lb[:plot_len], color_mean="b", color_shading="b", marker="v", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_2_np_mean[:plot_len], all_regrets_2_np_ub[:plot_len], all_regrets_2_np_lb[:plot_len], color_mean="r", color_shading="r", marker="D", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_3_np_mean[:plot_len], all_regrets_3_np_ub[:plot_len], all_regrets_3_np_lb[:plot_len], color_mean="g", color_shading="g", marker="s", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_4_np_mean[:plot_len], all_regrets_4_np_ub[:plot_len], all_regrets_4_np_lb[:plot_len], color_mean="c", color_shading="c", marker="o", marker_size=12)
plot_mean_and_CI_with_marker(inds[:plot_len], all_regrets_5_np_mean[:plot_len], all_regrets_5_np_ub[:plot_len], all_regrets_5_np_lb[:plot_len], color_mean="y", color_shading="y", marker="x", marker_size=12)

plt.legend((r"Neural UCB", r"Neural TS", \
            r"FN-UCB ($N=1$)", r"FN-UCB ($N=2$)", r"FN-UCB ($N=5$)", \
           ), prop={'size':16})

axes = plt.gca()
axes.set_xlim([0, 5000])
axes.set_ylim([0, 955])

plt.title("magic telescope, Fig. 2b")
plt.ylabel("Cumulative Regret")
plt.xlabel("Iterations")

plt.show()
